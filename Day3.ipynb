# %% [markdown]
# <a href="https://colab.research.google.com/github/sanjanakamat/ai-engineering-documentation/blob/main/Day3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install langchain langchain-google-genai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.3/73.3 kB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 567.0/567.0 kB 15.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 1.4.9
#     Uninstalling langchain-core-1.4.9:
#       Successfully uninstalled langchain-core-1.4.9
# ...

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
api_key = "AIzaSyCKVJGjnyJ6FXOqL5cCcYGd99VwYjk4STI"

# %%
llm = ChatGoogleGenerativeAI(
    model = "gemini-2.5-flash",
    temperature=0.7,
    google_api_key = api_key
)

# %%
prompt = "Suggest me a skill that is in demand?"
response = llm.invoke(prompt)
print(" Suggested Skill:\n", response)
# Out:
#  Suggested Skill:
# ...

# %%
template = "Give me 3 career skills that are in high demand in {year}."
prompt_template = PromptTemplate.from_template(template)

# %%
parser = StrOutputParser()

# %%
chain = prompt_template | llm | parser

# %%
response = chain.invoke({"year": "2026"})
print("\n Career Skills in 2026:\n", response)
# Out:
#  Career Skills in 2026:
#  Here are 3 career skills that are projected to be in high demand in 2026, along with why:
#
# 1.  **Applied AI & Data Fluency:**
#     *   **What it is:** This isn't just about being a data scientist or AI engineer, but about the ability for *everyone* to effectively leverage AI tools (like generative AI, predictive analytics, automation platforms) in their daily work, interpret data insights, ask the right questions of AI, and understand the ethical implications of using these technologies. It includes prompt engineering, understanding AI capabilities and limitations, and making data-driven decisions.
# ...
