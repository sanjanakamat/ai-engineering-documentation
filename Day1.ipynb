# %% [markdown]
# <a href="https://colab.research.google.com/github/sanjanakamat/ai-engineering-documentation/blob/main/Day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from transformers import AutoTokenizer
tokenizer=AutoTokenizer.from_pretrained("gpt2")
text="unhappiness"
tokens=tokenizer.tokenize(text)
print(tokens)
# Out:
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# ['un', 'h', 'appiness']

# %%
from transformers import AutoTokenizer
tokenizer=AutoTokenizer.from_pretrained("bert-base-uncased")
text="unhappiness"
tokens=tokenizer.tokenize(text)
print(tokens)
# Out:
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# ['un', '##ha', '##pp', '##iness']

# %%
from transformers import AutoTokenizer

text = "I am learning artificial intelligence."

# BERT tokenizer
bert = AutoTokenizer.from_pretrained(
    "bert-base-uncased"
)

# GPT-2 tokenizer
gpt2 = AutoTokenizer.from_pretrained(
    "gpt2"
)

print("BERT:")
print(bert.tokenize(text))

print("\nGPT-2:")
print(gpt2.tokenize(text))
# Out:
# BERT:
# ['i', 'am', 'learning', 'artificial', 'intelligence', '.']
#
# GPT-2:
# ['I', 'Ġam', 'Ġlearning', 'Ġartificial', 'Ġintelligence', '.']

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained(
    "bert-base-uncased"
)

text = "I am learning AI."

tokens = tokenizer.tokenize(text)

ids = tokenizer.convert_tokens_to_ids(tokens)

for token, token_id in zip(tokens, ids):
    print(token, "->", token_id)
# Out:
# i -> 1045
# am -> 2572
# learning -> 4083
# ai -> 9932
# . -> 1012

# %%
from transformers import pipeline

generator = pipeline(
    "text-generation",
    model="gpt2"
)

result = generator(
    "Artificial intelligence is",
    max_new_tokens=50,
    temperature=0.7,
    repetition_penalty=1.1,
    do_sample=True
)

print(result[0]["generated_text"])
# Out:
# model.safetensors: reconstructing file:   0%|          |  0.00B /  548MB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# [transformers] Passing `generation_config` together with generation-related arguments=({'temperature', 'do_sample', 'repetition_penalty', 'max_new_tokens'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# [transformers] Both `max_new_tokens` (=50) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# ...
